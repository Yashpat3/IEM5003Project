# %%
from gurobipy import *
import os
import csv

# %%
#os.getcwd()

# %%
os.chdir("C:\\Users\\yash1\\OneDrive - Oklahoma A and M System\\MAIN DRIVE\\Semester 3\\IEM 5013 (Introduction to optimization)\\Project_Final")

# %%
name1 = "ZJX_Central.csv"
name2 = "ZJX_East.csv"
name3 = "ZJX_North.csv"
name4 = "ZJX_South.csv"
name5 = "ZJX_West.csv"

with open(name1, 'r') as file:
    csv_reader = csv.reader(file)
    data = []

    for row in csv_reader:
        data.extend(row)

data_file_name = file.name
#print(data)

# %%
s = [32, 40]
r = [int(value) for value in data]

## limit input size for trial runs
#r = r[0:240]

# %%
s
# Out:
# [32, 40]

# %%
# Model Initiation
m = Model("Shift_Scheduling_Problem")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-12-06

# %%
######################################
########## Input parameters ##########
######################################
## Subscript 1 is for 8 hours shifts and 2 is for 10 hour shifts

# HOURLY cost of 1 shift
hcost = 1

# hours in 1 shift
h1 = 8
h2 = 10

# number of shifts in schedule
j1 = 10
j2 = 8

# cost of entire schedule
c1 = hcost*h1*j1
c2 = hcost*h2*j2

# overtime hourly cost
ot_hcost = 1.5 * hcost

# total number of schedules
n1 = 25
n2 = 25

# %%
i_indices = range(n1) #Total count of standard schedules
k_indices = range(n2) #Total count of compressed schedules

j1_indices = range(j1) #shift indices in standard schedule
j2_indices = range(j2) #shift indices in compressed schedule

t_indices = range(len(r)) #time period indices

# %%
########################################
########## Decision Variables ##########
########################################

###
### Schedule selection ###
S = m.addVars(i_indices, vtype=GRB.BINARY, name="S")
C = m.addVars(k_indices, vtype=GRB.BINARY, name="C")


###
### Normal Working Hours ### (only captures starting marks)
# Normal working hours initiation for each shift "j1" in standard schedule "i"
X = m.addVars(i_indices, t_indices, vtype=GRB.BINARY, name="X")

# Normal working hours initiation for each shift "j2" in compressed schedule "k"
Y = m.addVars(k_indices, t_indices, vtype=GRB.BINARY, name="Y")


###
### Overtime working hours ### (captures all the time periods that are active)
# Active period for Overtime in "i"th standard schedule's "j1"th shift
OS = m.addVars(i_indices, t_indices, vtype=GRB.BINARY, name="OS")

# Active period for Overtime in "k"th compressed schedule's "j2"th shift
OC = m.addVars(k_indices, t_indices, vtype=GRB.BINARY, name="OC")

# %%
########################################
########## Objective function ##########
########################################

expression01 = quicksum(c1 * S[i] for i in i_indices)
expression02 = quicksum(c2 * C[k] for k in k_indices)
expression03 = quicksum(ot_hcost * OS[i, t] for i in i_indices for t in t_indices)
expression04 = quicksum(ot_hcost * OC[k, t] for k in k_indices for t in t_indices)

# Set objective function
m.setObjective(expression01 + expression02 + expression03 + expression04, GRB.MINIMIZE)

# %%
#################################
########## Constraints ##########
#################################

###
### demand constraint

## POSSIBLE ERROR

for t in t_indices:
    time_range_normal = range(max(0, t-31), t+1)
    time_range_compressed = range(max(0, t-39), t+1)
    
    exp1 = quicksum(X[i, tau] for i in i_indices for tau in time_range_normal)
    exp2 = quicksum(Y[k, tau] for k in k_indices for tau in time_range_compressed)
    
    exp3 = quicksum(OS[i, t] for i in i_indices)
    exp4 = quicksum(OC[k, t] for k in k_indices)
    
    m.addConstr(exp1 + exp2 + exp3 + exp4 >= r[t], name=f"demand_constraint_{t}")

# %%
###
### OT continuation constraints
### Only gets affected by same values of "j"
for i in i_indices:
    for t in t_indices:
        if t >= s[0]:
            m.addConstr(OS[i, t] <= X[i, t-s[0]] + OS[i, t-1], name=f"OS_Cont_{i},{t}")

for k in k_indices:
    for t in t_indices:
        if t >= s[1]:
            m.addConstr(OC[k, t] <= Y[k, t-s[1]] + OC[k, t-1], name=f"OC_Cont_{k},{t}")

# %%
###
### 8-hours gap
### affected by other "j" of same "i"
# X & OS
for i in i_indices:
    for t in t_indices:
        time_check_range1 = range(max(0,t-63), t)           
        exp001 = quicksum(X[i, tau1] for tau1 in time_check_range1)
            
        time_check_range2 = range(max(0,t-32), t)           
        exp002 = quicksum(OS[i, tau2] for tau2 in time_check_range2)
            
        m.addConstr(100000*(1 - X[i, t]) >= exp001 + exp002, name=f"8hourGap_OS_{i}{t}")
            
# Y & OC
for k in k_indices:
    for t in t_indices:
        time_check_range1 = range(max(0,t-71), t)           
        exp101 = quicksum(Y[k, tau1] for tau1 in time_check_range1)
            
        time_check_range2 = range(max(0,t-32), t)           
        exp102 = quicksum(OC[k, tau2] for tau2 in time_check_range2)
            
        m.addConstr(100000*(1 - Y[k, t]) >= exp101 + exp102, name=f"8hourGap_OC_{k}{t}")

# %%
###
### Shift validation constraint
for i in i_indices:
    a = quicksum(X[i, t] for t in t_indices)
    b = 10*S[i]
    m.addConstr(a == b, name=f"shift_validation_S{i}")

for k in k_indices:
    a = quicksum(Y[k, t] for t in t_indices)
    b = 8*C[k]
    m.addConstr(a == b, name=f"shift_validation_C{k}")

# %%
###
### Last few shifts should not be initialized
for t in range(len(t_indices)-31, len(t_indices)):
    a = quicksum(X[i, t] for i in i_indices)
    m.addConstr(a == 0, name=f"last_zeroes_8hours_{t}")

for t in range(len(t_indices)-39, len(t_indices)):
    a = quicksum(Y[k, t] for k in k_indices)
    m.addConstr(a == 0, name=f"last_zeroes_10hours_{t}")

# %%
###
### OT can't start in initial time
for t in range(0, 32):
    a = quicksum(OS[i, t] for i in i_indices)
    m.addConstr(a == 0, name=f"Initial_OS_zero_{t}")
    
for t in range(0, 40):
    a = quicksum(OC[k, t] for k in k_indices)
    m.addConstr(a == 0, name=f"Initial_OC_zero_{t}")

# %%
###
###
#for i in i_indices:
#    for t in t_indices:
#        a = quicksum(X[i, t])
#        m.addConstr(a <= 1, name=f"one_shift_at_a_time_S_{i}{t}")
#
#for k in k_indices:
#    for t in t_indices:
#        a = quicksum(Y[k, t])
#        m.addConstr(a <= 1, name=f"one_shift_at_a_time_C_{k}{t}")

# %%
m.Params.timeLimit = 0.25*3600

m.optimize()
# Out:
# Set parameter TimeLimit to value 900
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11.0 (22621.2))
#
# CPU model: AMD Ryzen 7 5700U with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 134136 rows, 134450 columns and 9300800 nonzeros
# Model fingerprint: 0x4fe0a26b
# Variable types: 0 continuous, 134450 integer (134450 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [2e+00, 8e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+05]
# Found heuristic solution: objective 3659.0000000
# Presolve removed 1962 rows and 3550 columns (presolve time = 5s) ...
# Presolve removed 2064 rows and 3550 columns (presolve time = 10s) ...
# Presolve removed 2264 rows and 3550 columns (presolve time = 15s) ...
# Presolve removed 2269 rows and 3550 columns (presolve time = 20s) ...
# Presolve removed 3534 rows and 3550 columns (presolve time = 25s) ...
# Presolve removed 3534 rows and 3550 columns (presolve time = 30s) ...
# Presolve removed 3534 rows and 3550 columns (presolve time = 35s) ...
# Sparsify removed 2038752 nonzeros (23%)
# Presolve removed 3534 rows and 577 columns
# Presolve time: 39.53s
# Presolved: 130602 rows, 133873 columns, 6911898 nonzeros
# Variable types: 0 continuous, 133873 integer (130905 binary)
# Found heuristic solution: objective 3654.5000000
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.30s
#
# Barrier performed 0 iterations in 44.80 seconds (57.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3011    2.1975000e+03   0.000000e+00   0.000000e+00     45s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#      138 DPushes remaining with DInf 0.0000000e+00                45s
#        0 DPushes remaining with DInf 0.0000000e+00                45s
#
#     3439 PPushes remaining with PInf 0.0000000e+00                45s
#        0 PPushes remaining with PInf 0.0000000e+00                45s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 9.2983681e+02     45s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6580    2.1975000e+03   0.000000e+00   9.298368e+02     46s
#     7913    2.1975000e+03   0.000000e+00   0.000000e+00     46s
#
# Root relaxation: objective 2.197500e+03, 7913 iterations, 4.50 seconds (4.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2197.50000    0  746 3654.50000 2197.50000  39.9%     -   49s
# H    0     0                    3648.5000000 2197.50000  39.8%     -   52s
# H    0     0                    3626.0000000 2197.50000  39.4%     -   54s
#      0     0 2197.50000    0 1096 3626.00000 2197.50000  39.4%     -   67s
# H    0     0                    3617.0000000 2197.50000  39.2%     -   69s
# H    0     0                    2240.0000000 2197.50000  1.90%     -   97s
#      0     0 2197.50000    0 1335 2240.00000 2197.50000  1.90%     -   99s
#      0     0 2197.50000    0  921 2240.00000 2197.50000  1.90%     -  115s
#      0     0 2197.50000    0 1585 2240.00000 2197.50000  1.90%     -  120s
#      0     0 2197.50000    0  769 2240.00000 2197.50000  1.90%     -  131s
#      0     0 2197.50000    0 1346 2240.00000 2197.50000  1.90%     -  136s
#      0     0 2197.50000    0  443 2240.00000 2197.50000  1.90%     -  149s
#      0     0 2197.50000    0  754 2240.00000 2197.50000  1.90%     -  157s
#      0     0 2197.50000    0  574 2240.00000 2197.50000  1.90%     -  188s
#      0     0 2197.50000    0  714 2240.00000 2197.50000  1.90%     -  192s
#      0     0 2197.50000    0  467 2240.00000 2197.50000  1.90%     -  201s
#      0     0 2197.50000    0  461 2240.00000 2197.50000  1.90%     -  205s
#      0     0 2197.50000    0  723 2240.00000 2197.50000  1.90%     -  216s
#      0     0 2197.50000    0  723 2240.00000 2197.50000  1.90%     -  233s
# H    0     0                    2197.5000000 2197.50000  0.00%     -  242s
#      0     0 2197.50000    0  723 2197.50000 2197.50000  0.00%     -  242s
#
# Cutting planes:
#   Gomory: 5
#   Lift-and-project: 1
#   Cover: 144
#   Implied bound: 1
#   Clique: 84
#   MIR: 113
#   StrongCG: 18
#   GUB cover: 13
#   Zero half: 12
#   RLT: 15
#   Relax-and-lift: 7
#
# Explored 1 nodes (66118 simplex iterations) in 242.27 seconds (223.78 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 2197.5 2240 3617 ... 3659
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.197500000000e+03, best bound 2.197500000000e+03, gap 0.0000%

# %%
for i in i_indices:
    for t in t_indices:
        if OS[i, t].x != 0:
            print(f"[{i},{t}]")
# Out:
# [1,1118]
# [2,362]
# [2,1034]
# [2,1150]
# [4,433]
# [5,1118]
# [6,478]
# [7,446]
# [8,446]
# [10,750]

# %%
model_status = ""

if m.status == GRB.OPTIMAL:
    model_status += f"Termination status: Optimal\n"
    model_status += f"Best objective value: {m.objVal}\n"
    model_status += f"Elapsed wall-clock time: {m.Runtime} seconds\n"
    model_status += f"Optimality gap at termination: {m.MIPGap}%\n"
elif m.status == GRB.INFEASIBLE:
    model_status += "Termination status: Infeasible\n"
    model_status += f"Infeasibility reason: {m.UnbdRay}\n"
elif m.status == GRB.UNBOUNDED:
    model_status += "Termination status: Unbounded\n"
elif m.status == GRB.TIME_LIMIT:
    model_status += "Termination status: Time Limit Exceeded\n"
    model_status += f"Best objective value: {m.objVal}\n"
    model_status += f"Optimality gap at termination: {m.MIPGap}%\n"
else:
    model_status += f"Optimization terminated with status: {m.status}\n"

print(model_status)
# Out:
# Termination status: Optimal
# Best objective value: 2197.5
# Elapsed wall-clock time: 242.3090000152588 seconds
# Optimality gap at termination: 0.0%

# %%
distribution_text = ""

# %%
if m.status == GRB.OPTIMAL:
    distribution_text += "*****STANDARD SCHEDULES*****\n\n"
    for i in i_indices:
        distribution_text += f"Schedule {i}:"
        a = 1
        for t in t_indices:
            if X[i, t].x != 0:
                distribution_text += f"\nShift {a} starts at period: {t}"
                a += 1
            elif OS[i, t].x != 0:
                if OS[i, max(0, t-1)].x == 0:
                    distribution_text += f" || overtime starts at {t}"
                else:
                    pass
                
                if OS[i, min(t+1, len(t_indices))].x == 0:
                    distribution_text += f" and ends at {t}"
                else:
                    pass
        distribution_text += "\n"

print(distribution_text)
# Out:
# *****STANDARD SCHEDULES*****
#
# Schedule 0:
# Shift 1 starts at period: 126
# Shift 2 starts at period: 313
# Shift 3 starts at period: 507
# Shift 4 starts at period: 736
# Shift 5 starts at period: 814
# Shift 6 starts at period: 885
# Shift 7 starts at period: 988
# Shift 8 starts at period: 1115
# Shift 9 starts at period: 1219
# Shift 10 starts at period: 1309
# Schedule 1:
# Shift 1 starts at period: 70
# Shift 2 starts at period: 157
# Shift 3 starts at period: 314
# Shift 4 starts at period: 413
# Shift 5 starts at period: 540
# Shift 6 starts at period: 604
# Shift 7 starts at period: 733
# Shift 8 starts at period: 989
# Shift 9 starts at period: 1086 || overtime starts at 1118 and ends at 1118
# Shift 10 starts at period: 1190
# Schedule 2:
# Shift 1 starts at period: 157
# Shift 2 starts at period: 228
# Shift 3 starts at period: 330 || overtime starts at 362 and ends at 362
# Shift 4 starts at period: 445
# Shift 5 starts at period: 524
# Shift 6 starts at period: 637
# Shift 7 starts at period: 742
# Shift 8 starts at period: 1002 || overtime starts at 1034 and ends at 1034
# Shift 9 starts at period: 1118 || overtime starts at 1150 and ends at 1150
# Shift 10 starts at period: 1273
# Schedule 3:
# Shift 1 starts at period: 35
# Shift 2 starts at period: 144
# Shift 3 starts at period: 219
# Shift 4 starts at period: 409
# Shift 5 starts at period: 509
# Shift 6 starts at period: 605
# Shift 7 starts at period: 732
# Shift 8 starts at period: 845
# Shift 9 starts at period: 940
# Shift 10 starts at period: 1017
# Schedule 4:
# Shift 1 starts at period: 50
# Shift 2 starts at period: 316
# Shift 3 starts at period: 401 || overtime starts at 433 and ends at 433
# Shift 4 starts at period: 518
# Shift 5 starts at period: 612
# Shift 6 starts at period: 700
# Shift 7 starts at period: 898
# Shift 8 starts at period: 1007
# Shift 9 starts at period: 1122
# Shift 10 starts at period: 1211
# Schedule 5:
# Shift 1 starts at period: 31
# Shift 2 starts at period: 254
# Shift 3 starts at period: 330
# Shift 4 starts at period: 425
# Shift 5 starts at period: 623
# Shift 6 starts at period: 701
# Shift 7 starts at period: 798
# Shift 8 starts at period: 1018
# Shift 9 starts at period: 1086 || overtime starts at 1118 and ends at 1118
# Shift 10 starts at period: 1310
# Schedule 6:
# Shift 1 starts at period: 121
# Shift 2 starts at period: 226
# Shift 3 starts at period: 342
# Shift 4 starts at period: 446 || overtime starts at 478 and ends at 478
# Shift 5 starts at period: 536
# Shift 6 starts at period: 626
# Shift 7 starts at period: 793
# Shift 8 starts at period: 990
# Shift 9 starts at period: 1184
# Shift 10 starts at period: 1275
# Schedule 7:
# Shift 1 starts at period: 61
# Shift 2 starts at period: 220
# Shift 3 starts at period: 300
# Shift 4 starts at period: 414 || overtime starts at 446 and ends at 446
# Shift 5 starts at period: 513
# Shift 6 starts at period: 704
# Shift 7 starts at period: 892
# Shift 8 starts at period: 1021
# Shift 9 starts at period: 1085
# Shift 10 starts at period: 1278
# Schedule 8:
# Shift 1 starts at period: 29
# Shift 2 starts at period: 213
# Shift 3 starts at period: 350
# Shift 4 starts at period: 414 || overtime starts at 446 and ends at 446
# Shift 5 starts at period: 638
# Shift 6 starts at period: 724
# Shift 7 starts at period: 820
# Shift 8 starts at period: 978
# Shift 9 starts at period: 1098
# Shift 10 starts at period: 1305
# Schedule 9:
# Shift 1 starts at period: 28
# Shift 2 starts at period: 160
# Shift 3 starts at period: 252
# Shift 4 starts at period: 316
# Shift 5 starts at period: 442
# Shift 6 starts at period: 507
# Shift 7 starts at period: 701
# Shift 8 starts at period: 830
# Shift 9 starts at period: 925
# Shift 10 starts at period: 1074
# Schedule 10:
# Shift 1 starts at period: 150
# Shift 2 starts at period: 316
# Shift 3 starts at period: 448
# Shift 4 starts at period: 517
# Shift 5 starts at period: 606
# Shift 6 starts at period: 718 || overtime starts at 750 and ends at 750
# Shift 7 starts at period: 824
# Shift 8 starts at period: 924
# Shift 9 starts at period: 988
# Shift 10 starts at period: 1214
# Schedule 11:
# Shift 1 starts at period: 18
# Shift 2 starts at period: 252
# Shift 3 starts at period: 412
# Shift 4 starts at period: 548
# Shift 5 starts at period: 637
# Shift 6 starts at period: 833
# Shift 7 starts at period: 915
# Shift 8 starts at period: 1023
# Shift 9 starts at period: 1101
# Shift 10 starts at period: 1309
# Schedule 12:
# Shift 1 starts at period: 60
# Shift 2 starts at period: 149
# Shift 3 starts at period: 269
# Shift 4 starts at period: 351
# Shift 5 starts at period: 475
# Shift 6 starts at period: 732
# Shift 7 starts at period: 877
# Shift 8 starts at period: 972
# Shift 9 starts at period: 1181
# Shift 10 starts at period: 1284
# Schedule 13:
# Schedule 14:
# Shift 1 starts at period: 60
# Shift 2 starts at period: 124
# Shift 3 starts at period: 248
# Shift 4 starts at period: 334
# Shift 5 starts at period: 500
# Shift 6 starts at period: 697
# Shift 7 starts at period: 792
# Shift 8 starts at period: 901
# Shift 9 starts at period: 990
# Shift 10 starts at period: 1084
# Schedule 15:
# Shift 1 starts at period: 62
# Shift 2 starts at period: 351
# Shift 3 starts at period: 443
# Shift 4 starts at period: 541
# Shift 5 starts at period: 652
# Shift 6 starts at period: 797
# Shift 7 starts at period: 921
# Shift 8 starts at period: 1019
# Shift 9 starts at period: 1174
# Shift 10 starts at period: 1277
# Schedule 16:
# Shift 1 starts at period: 56
# Shift 2 starts at period: 173
# Shift 3 starts at period: 317
# Shift 4 starts at period: 603
# Shift 5 starts at period: 702
# Shift 6 starts at period: 829
# Shift 7 starts at period: 893
# Shift 8 starts at period: 1002
# Shift 9 starts at period: 1117
# Shift 10 starts at period: 1271
# Schedule 17:
# Schedule 18:
# Schedule 19:
# Schedule 20:
# Shift 1 starts at period: 121
# Shift 2 starts at period: 216
# Shift 3 starts at period: 345
# Shift 4 starts at period: 496
# Shift 5 starts at period: 603
# Shift 6 starts at period: 684
# Shift 7 starts at period: 790
# Shift 8 starts at period: 888
# Shift 9 starts at period: 1179
# Shift 10 starts at period: 1295
# Schedule 21:
# Schedule 22:
# Shift 1 starts at period: 29
# Shift 2 starts at period: 122
# Shift 3 starts at period: 203
# Shift 4 starts at period: 336
# Shift 5 starts at period: 433
# Shift 6 starts at period: 513
# Shift 7 starts at period: 631
# Shift 8 starts at period: 724
# Shift 9 starts at period: 1006
# Shift 10 starts at period: 1269
# Schedule 23:
# Schedule 24:

# %%
if m.status == GRB.OPTIMAL:
    distribution_text += "\n\n\n*****COMPRESSED SCHEDULES*****\n\n"
    for k in k_indices:
        distribution_text += f"Schedule {k}:"
        a = 1
        for t in t_indices:
            if Y[k, t].x != 0:
                distribution_text += f"\nShift {a} starts at period: {t}"
                a += 1
            elif OC[k, t].x != 0:
                if OC[k, max(0, t-1)].x == 0:
                    distribution_text += f" || overtime starts at {t}"
                else:
                    pass
                
                if OC[k, min(t+1, len(t_indices))].x == 0:
                    distribution_text += f" and ends at {t}"
                else:
                    pass
        distribution_text += "\n"

print(distribution_text)
# Out:
# *****STANDARD SCHEDULES*****
#
# Schedule 0:
# Shift 1 starts at period: 126
# Shift 2 starts at period: 313
# Shift 3 starts at period: 507
# Shift 4 starts at period: 736
# Shift 5 starts at period: 814
# Shift 6 starts at period: 885
# Shift 7 starts at period: 988
# Shift 8 starts at period: 1115
# Shift 9 starts at period: 1219
# Shift 10 starts at period: 1309
# Schedule 1:
# Shift 1 starts at period: 70
# Shift 2 starts at period: 157
# Shift 3 starts at period: 314
# Shift 4 starts at period: 413
# Shift 5 starts at period: 540
# Shift 6 starts at period: 604
# Shift 7 starts at period: 733
# Shift 8 starts at period: 989
# Shift 9 starts at period: 1086 || overtime starts at 1118 and ends at 1118
# Shift 10 starts at period: 1190
# Schedule 2:
# Shift 1 starts at period: 157
# Shift 2 starts at period: 228
# Shift 3 starts at period: 330 || overtime starts at 362 and ends at 362
# Shift 4 starts at period: 445
# Shift 5 starts at period: 524
# Shift 6 starts at period: 637
# Shift 7 starts at period: 742
# Shift 8 starts at period: 1002 || overtime starts at 1034 and ends at 1034
# Shift 9 starts at period: 1118 || overtime starts at 1150 and ends at 1150
# Shift 10 starts at period: 1273
# Schedule 3:
# Shift 1 starts at period: 35
# Shift 2 starts at period: 144
# Shift 3 starts at period: 219
# Shift 4 starts at period: 409
# Shift 5 starts at period: 509
# Shift 6 starts at period: 605
# Shift 7 starts at period: 732
# Shift 8 starts at period: 845
# Shift 9 starts at period: 940
# Shift 10 starts at period: 1017
# Schedule 4:
# Shift 1 starts at period: 50
# Shift 2 starts at period: 316
# Shift 3 starts at period: 401 || overtime starts at 433 and ends at 433
# Shift 4 starts at period: 518
# Shift 5 starts at period: 612
# Shift 6 starts at period: 700
# Shift 7 starts at period: 898
# Shift 8 starts at period: 1007
# Shift 9 starts at period: 1122
# Shift 10 starts at period: 1211
# Schedule 5:
# Shift 1 starts at period: 31
# Shift 2 starts at period: 254
# Shift 3 starts at period: 330
# Shift 4 starts at period: 425
# Shift 5 starts at period: 623
# Shift 6 starts at period: 701
# Shift 7 starts at period: 798
# Shift 8 starts at period: 1018
# Shift 9 starts at period: 1086 || overtime starts at 1118 and ends at 1118
# Shift 10 starts at period: 1310
# Schedule 6:
# Shift 1 starts at period: 121
# Shift 2 starts at period: 226
# Shift 3 starts at period: 342
# Shift 4 starts at period: 446 || overtime starts at 478 and ends at 478
# Shift 5 starts at period: 536
# Shift 6 starts at period: 626
# Shift 7 starts at period: 793
# Shift 8 starts at period: 990
# Shift 9 starts at period: 1184
# Shift 10 starts at period: 1275
# Schedule 7:
# Shift 1 starts at period: 61
# Shift 2 starts at period: 220
# Shift 3 starts at period: 300
# Shift 4 starts at period: 414 || overtime starts at 446 and ends at 446
# Shift 5 starts at period: 513
# Shift 6 starts at period: 704
# Shift 7 starts at period: 892
# Shift 8 starts at period: 1021
# Shift 9 starts at period: 1085
# Shift 10 starts at period: 1278
# Schedule 8:
# Shift 1 starts at period: 29
# Shift 2 starts at period: 213
# Shift 3 starts at period: 350
# Shift 4 starts at period: 414 || overtime starts at 446 and ends at 446
# Shift 5 starts at period: 638
# Shift 6 starts at period: 724
# Shift 7 starts at period: 820
# Shift 8 starts at period: 978
# Shift 9 starts at period: 1098
# Shift 10 starts at period: 1305
# Schedule 9:
# Shift 1 starts at period: 28
# Shift 2 starts at period: 160
# Shift 3 starts at period: 252
# Shift 4 starts at period: 316
# Shift 5 starts at period: 442
# Shift 6 starts at period: 507
# Shift 7 starts at period: 701
# Shift 8 starts at period: 830
# Shift 9 starts at period: 925
# Shift 10 starts at period: 1074
# Schedule 10:
# Shift 1 starts at period: 150
# Shift 2 starts at period: 316
# Shift 3 starts at period: 448
# Shift 4 starts at period: 517
# Shift 5 starts at period: 606
# Shift 6 starts at period: 718 || overtime starts at 750 and ends at 750
# Shift 7 starts at period: 824
# Shift 8 starts at period: 924
# Shift 9 starts at period: 988
# Shift 10 starts at period: 1214
# Schedule 11:
# Shift 1 starts at period: 18
# Shift 2 starts at period: 252
# Shift 3 starts at period: 412
# Shift 4 starts at period: 548
# Shift 5 starts at period: 637
# Shift 6 starts at period: 833
# Shift 7 starts at period: 915
# Shift 8 starts at period: 1023
# Shift 9 starts at period: 1101
# Shift 10 starts at period: 1309
# Schedule 12:
# Shift 1 starts at period: 60
# Shift 2 starts at period: 149
# Shift 3 starts at period: 269
# Shift 4 starts at period: 351
# Shift 5 starts at period: 475
# Shift 6 starts at period: 732
# Shift 7 starts at period: 877
# Shift 8 starts at period: 972
# Shift 9 starts at period: 1181
# Shift 10 starts at period: 1284
# Schedule 13:
# Schedule 14:
# Shift 1 starts at period: 60
# Shift 2 starts at period: 124
# Shift 3 starts at period: 248
# Shift 4 starts at period: 334
# Shift 5 starts at period: 500
# Shift 6 starts at period: 697
# Shift 7 starts at period: 792
# Shift 8 starts at period: 901
# Shift 9 starts at period: 990
# Shift 10 starts at period: 1084
# Schedule 15:
# Shift 1 starts at period: 62
# Shift 2 starts at period: 351
# Shift 3 starts at period: 443
# Shift 4 starts at period: 541
# Shift 5 starts at period: 652
# Shift 6 starts at period: 797
# Shift 7 starts at period: 921
# Shift 8 starts at period: 1019
# Shift 9 starts at period: 1174
# Shift 10 starts at period: 1277
# Schedule 16:
# Shift 1 starts at period: 56
# Shift 2 starts at period: 173
# Shift 3 starts at period: 317
# Shift 4 starts at period: 603
# Shift 5 starts at period: 702
# Shift 6 starts at period: 829
# Shift 7 starts at period: 893
# Shift 8 starts at period: 1002
# Shift 9 starts at period: 1117
# Shift 10 starts at period: 1271
# Schedule 17:
# Schedule 18:
# Schedule 19:
# Schedule 20:
# Shift 1 starts at period: 121
# Shift 2 starts at period: 216
# Shift 3 starts at period: 345
# Shift 4 starts at period: 496
# Shift 5 starts at period: 603
# Shift 6 starts at period: 684
# Shift 7 starts at period: 790
# Shift 8 starts at period: 888
# Shift 9 starts at period: 1179
# Shift 10 starts at period: 1295
# Schedule 21:
# Schedule 22:
# Shift 1 starts at period: 29
# Shift 2 starts at period: 122
# Shift 3 starts at period: 203
# Shift 4 starts at period: 336
# Shift 5 starts at period: 433
# Shift 6 starts at period: 513
# Shift 7 starts at period: 631
# Shift 8 starts at period: 724
# Shift 9 starts at period: 1006
# Shift 10 starts at period: 1269
# Schedule 23:
# Schedule 24:
#
#
#
# *****COMPRESSED SCHEDULES*****
#
# Schedule 0:
# Shift 1 starts at period: 0
# Shift 2 starts at period: 102
# Shift 3 starts at period: 326
# Shift 4 starts at period: 422
# Shift 5 starts at period: 613 || overtime starts at 653 and ends at 654
# Shift 6 starts at period: 799
# Shift 7 starts at period: 891
# Shift 8 starts at period: 1198
# Schedule 1:
# Schedule 2:
# Shift 1 starts at period: 31
# Shift 2 starts at period: 425
# Shift 3 starts at period: 616
# Shift 4 starts at period: 714
# Shift 5 starts at period: 806
# Shift 6 starts at period: 904 || overtime starts at 944 and ends at 944
# Shift 7 starts at period: 1097
# Shift 8 starts at period: 1193
# Schedule 3:
# Schedule 4:
# Schedule 5:
# Schedule 6:
# Schedule 7:
# Shift 1 starts at period: 137
# Shift 2 starts at period: 231
# Shift 3 starts at period: 421
# Shift 4 starts at period: 514
# Shift 5 starts at period: 810
# Shift 6 starts at period: 998
# Shift 7 starts at period: 1162
# Shift 8 starts at period: 1251
# Schedule 8:
# Shift 1 starts at period: 40
# Shift 2 starts at period: 138
# Shift 3 starts at period: 585
# Shift 4 starts at period: 708 || overtime starts at 748 and ends at 750
# Shift 5 starts at period: 904
# Shift 6 starts at period: 1092
# Shift 7 starts at period: 1183
# Shift 8 starts at period: 1287
# Schedule 9:
# Schedule 10:
# Shift 1 starts at period: 42
# Shift 2 starts at period: 127
# Shift 3 starts at period: 233 || overtime starts at 273 and ends at 273
# Shift 4 starts at period: 600
# Shift 5 starts at period: 712
# Shift 6 starts at period: 902
# Shift 7 starts at period: 1190
# Shift 8 starts at period: 1304
# Schedule 11:
# Schedule 12:
# Schedule 13:
# Shift 1 starts at period: 36 || overtime starts at 76 and ends at 78
# Shift 2 starts at period: 128
# Shift 3 starts at period: 231
# Shift 4 starts at period: 418
# Shift 5 starts at period: 774
# Shift 6 starts at period: 1090
# Shift 7 starts at period: 1184
# Shift 8 starts at period: 1285 || overtime starts at 1325 and ends at 1326
# Schedule 14:
# Shift 1 starts at period: 136
# Shift 2 starts at period: 220
# Shift 3 starts at period: 512
# Shift 4 starts at period: 618
# Shift 5 starts at period: 809
# Shift 6 starts at period: 1033 || overtime starts at 1073 and ends at 1073
# Shift 7 starts at period: 1124
# Shift 8 starts at period: 1206
# Schedule 15:
# Schedule 16:
# Shift 1 starts at period: 39
# Shift 2 starts at period: 232 || overtime starts at 272 and ends at 272
# Shift 3 starts at period: 545
# Shift 4 starts at period: 799
# Shift 5 starts at period: 905 || overtime starts at 945 and ends at 945
# Shift 6 starts at period: 1095
# Shift 7 starts at period: 1186
# Shift 8 starts at period: 1291
# Schedule 17:
# Schedule 18:
# Schedule 19:
# Schedule 20:
# Shift 1 starts at period: 134
# Shift 2 starts at period: 361
# Shift 3 starts at period: 523
# Shift 4 starts at period: 703
# Shift 5 starts at period: 808
# Shift 6 starts at period: 1085
# Shift 7 starts at period: 1171
# Shift 8 starts at period: 1292
# Schedule 21:
# Schedule 22:
# Schedule 23:
# Schedule 24:

# %%
file_path = "PatelPatelBhandari_part02.txt"

# %%
with open(file_path, "a") as file:
    file.write(f"For data obtained from {data_file_name}:\n\n")
    file.write("Model Status:\n")
    file.write(model_status)
    file.write("\n")
    file.write("Shift_Scheduling_Problem_results:\n")
    file.write(distribution_text)
    file.write("\n\n--XX--XX--XX--XX--XX--XX--XX--XX--XX--XX--XX--XX--XX--\n\n")
